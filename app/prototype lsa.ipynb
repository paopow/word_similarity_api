# %%
from gensim import corpora, models, similarities
import pandas as pd

# %%
dict_fabric = corpora.Dictionary.load("../lsaModels/dictionary_fabric")
lsi_fabric = models.LsiModel.load("../lsaModels/lsi_300_fabric")

# %%
lsi_fabric.print_topics()
# Out:
# [u'-0.493*"change" + -0.337*"color" + -0.289*"clothing" + -0.271*"clothes" + -0.198*"fabric" + -0.182*"make" + -0.181*"display" + -0.161*"colors" + -0.147*"mood" + -0.133*"changing"',
#  u'-0.470*"movies" + -0.354*"watch" + 0.317*"change" + -0.266*"show" + 0.245*"color" + -0.218*"screen" + 0.206*"clothes" + -0.171*"fabric" + -0.160*"movie" + -0.155*"display"',
#  u'0.538*"clothing" + -0.375*"movies" + 0.237*"display" + -0.235*"watch" + -0.221*"clothes" + -0.212*"change" + -0.201*"show" + 0.198*"advertising" + -0.196*"color" + 0.194*"interactive"',
#  u'0.561*"clothing" + 0.352*"movies" + 0.273*"show" + -0.264*"movie" + -0.228*"screen" + -0.224*"make" + 0.170*"watch" + -0.155*"fabric" + -0.147*"wall" + -0.138*"portable"',
#  u'0.424*"screen" + 0.418*"movie" + -0.335*"show" + 0.311*"clothing" + -0.251*"interactive" + -0.205*"games" + -0.194*"make" + -0.164*"game" + 0.156*"tv" + 0.138*"color"']

# %%
lsi_fabric.num_topics
# Out:
# 200

# %%
# method 1: put all into one big bag of words and do queries that way. corpus is the paths
paths = pd.read_csv("../topicWords/fabric_paths_smaller.csv")

# %%
paths['allwords'] = [p.encode('utf-8', 'ignore') for p in paths['allwords']]

# %%
path_corpus = [dict_fabric.doc2bow(p.split()) for p in paths['allwords']]
path_corpus[0]
# Out:
# [(9, 1),
#  (28, 1),
#  (32, 1),
#  (173, 2),
#  (385, 1),
#  (481, 1),
#  (505, 1),
#  (586, 1),
#  (602, 1),
#  (664, 1),
#  (1289, 1),
#  (1432, 2),
#  (1433, 1),
#  (1434, 1),
#  (1443, 1),
#  (1632, 1),
#  (1891, 1)]

# %%
index = similarities.MatrixSimilarity(lsi_fabric[path_corpus])
index
# Out:
# WARNING:gensim.similarities.docsim:scanning corpus to determine the number of features (consider setting `num_features` explicitly)

# %%
index.index
# Out:
# array([[-0.29538864,  0.03366122,  0.0257112 , ..., -0.02557454,
#          0.00967514, -0.02686297],
#        [-0.12921008, -0.09690642,  0.15108968, ...,  0.09126988,
#         -0.0397026 ,  0.04123164],
#        [-0.1019632 , -0.17350984, -0.03546882, ...,  0.02731007,
#          0.05460421,  0.00503987],
#        [-0.17824575,  0.05087417, -0.04662385, ...,  0.01324272,
#         -0.00159962,  0.01131967],
#        [-0.24498549, -0.16139869,  0.29300216, ..., -0.03072298,
#         -0.01128992, -0.00553972],
#        [-0.17061396, -0.13212545,  0.1837122 , ...,  0.01545442,
#          0.02593173, -0.00515088]], dtype=float32)

# %%
# get a sample vector
def choose_best_path(ideaBag, dictionary, lsimodel, simIndex, paths):
    """Given a bag of words that comprises a set of ideas,
    return a rank ordered list of the most similar paths
    """
    
    # preprocess and project into lsi space
    vec_bow = dictionary.doc2bow(ideaBag.lower().split())
    vec_lsi = lsimodel[vec_bow]
    # print vec_lsi
    
    # get similarities
    # print simIndex
    sims = simIndex[vec_lsi]
    sims = sorted(enumerate(sims), key=lambda item: -item[1])
    
    paths['rank'] = 0
    paths['sim'] = 0.0
    for rank, docSim in enumerate(sims):
        # print docSim
        paths.set_value(docSim[0], 'rank', rank)
        paths.set_value(docSim[0], 'sim', docSim[1])
        
    paths.sort_values("rank", inplace=True)
    
    return paths

# %%
sim_paths = choose_best_path(paths.loc[1, 'allwords'], dict_fabric, lsi_fabric, index, paths)
# Out:
# [(0, -0.44648702415151126), (1, -0.38003707691639288), (2, 0.60112395057086465), (3, -0.29883381990441438), (4, -0.32076219508783316), (5, -0.066574690546653062), (6, -0.073162399638100853), (7, 0.07350197403762615), (8, 0.055585881876337881), (9, 0.44540561807074014), (10, 0.35291759203293765), (11, 0.39440476331477137), (12, 0.043086028945357249), (13, -0.83575141585438928), (14, 0.30573082687306913), (15, -0.12020533339729102), (16, -0.12971492052835498), (17, -0.13418573617601454), (18, -0.080486562914614812), (19, -0.11318126224120675), (20, 0.26392790307368286), (21, 0.41367824856591034), (22, -0.035035035774489943), (23, 0.0010996381111193691), (24, 0.20003918494109688), (25, -0.0025126602032651828), (26, 0.0075354683128957068), (27, -0.17568141032406306), (28, 0.16577943745923854), (29, -0.12096586494118729), (30, -0.069728449205058163), (31, -0.22591806126418043), (32, -0.045224805632126303), (33, -0.17889896330055263), (34, 0.17404782651881989), (35, -0.0064552961507992846), (36, -0.037936711804725326), (37, -0.33612319579454258), (38, 0.33524011927158315), (39, -0.0084322150755474033), (40, 0.023383210429843752), (41, -0.22102394712089668), (42, -0.22787504674963205), (43, 0.13435785622692087), (44, 0.24855423342476593), (45, -0.12995678120794998), (46, 0.023357295583685524), (47, -0.04677681075274729), (48, -0.25131097810771486), (49, -0.10291141114014865), (50, 0.06918614386482147), (51, -0.078268225275809192), (52, 0.15089754868968869), (53, -0.14296583344012204), (54, -0.16662853192660207), (55, -0.2543807441303198), (56, 0.27968534976308551), (57, 0.00042728518036417207), (58, 0.11883150176691377), (59, -0.12099668286218282), (60, 0.088920351565215924), (61, -0.02974310779811597), (62, -0.11395810371693289), (63, -0.071081219770589316), (64, 0.10674379415537673), (65, -0.18297798955532435), (66, 0.069525904269208294), (67, -0.0079634660331693516), (68, -0.020927502881546774), (69, 0.17288041747083255), (70, -0.038329996213494852), (71, -0.21994380996072752), (72, -0.15478122476431741), (73, 0.082425841708092168), (74, -0.018295841031914901), (75, 0.16564816125806123), (76, -0.066363084810496784), (77, 0.0093265349914392059), (78, -0.023053679717718194), (79, 0.046463536078708678), (80, 0.18939129157424051), (81, 0.21544131530104896), (82, 0.26675085695057604), (83, -0.25343292975131537), (84, -0.1658277404357647), (85, -0.027094260777190352), (86, -0.068828762502297844), (87, 0.064089507930827627), (88, -0.082688047306782517), (89, -0.0023717866257315524), (90, 0.090109838820738183), (91, -0.060765920437549088), (92, 0.019131006735966974), (93, -0.042571885795865905), (94, 0.14176170684754391), (95, -0.05558748742993657), (96, -0.017795821904040464), (97, -0.045915444370369742), (98, 0.069577081968068902), (99, 0.10995370834114208), (100, -0.31328629751489051), (101, -0.14959286368000907), (102, 0.016645779168646326), (103, 0.19874459788533624), (104, -0.10945459970594512), (105, -0.28422200605352088), (106, 0.093913287567946008), (107, 0.51864410732169086), (108, -0.10172823461159161), (109, -0.23628972068220494), (110, -0.52318445250550139), (111, -0.018374565343039995), (112, -0.10243556175785715), (113, -0.073032096378951139), (114, 0.21088682595402569), (115, 0.14891980438118255), (116, 0.217414806181154), (117, -0.46015226026702333), (118, 0.16041587883439784), (119, -0.055779684678814861), (120, 0.098793920860771656), (121, -0.054511087097026782), (122, 0.17920732554735325), (123, -0.34771751147120533), (124, 0.31879046624296559), (125, 0.43013508030673758), (126, 0.25828213457150107), (127, 0.30441960610162155), (128, 0.023764586197649578), (129, -0.10969776579690113), (130, 0.077705546075136175), (131, 0.065646443005001998), (132, -0.067614655583791455), (133, 0.099993181106345475), (134, -0.087387794894566648), (135, -0.35687590609273184), (136, 0.64454915473738339), (137, 0.065684811025207374), (138, -0.13182865047255857), (139, 0.045234890377092989), (140, -0.084067216573465095), (141, 0.26466525722 ...
# MatrixSimilarity<6 docs, 200 features>

# %%
sim_paths.sort_values("rank", inplace=True)
sim_paths
# Out:
#     id                                               path  \
# 1  p03     enhance the customer experience at restaurants
# 4  p06  make and display more effective advertisements...
# 5  p10  make physically interactive games for the ente...
# 0  p01  create novel ways for visual artists to expres...
# 2  p04  enhance the educational experience of students...
# 3  p05  increase productivity/efficiency in everyday life
#
#                                                  ex1  \
# 1  chef coats could display food images of the me...
# 4  Airplane draggable banner that can display any...
# 5  Make soft interactive baby toys that are safe ...
# 0  Use it as a canvas for art, as it reacts to to...
# 2  It can be used in school as a way to show kids...
# 3  a shirt that you can load data into the sleeve...
#
#                                                  ex2  \
# 1  Interactive menus at restaurants - press to le...
# 4  Personalized billboards from companies that re...
# 5  Dance floor carpet that flashes the next foot ...
# 0  It would be great for making a canvas for arti...
# 2                Interactive text books for students
# 3  ability to write notes on clothes with touch s...
#
#                                             allwords  rank       sim
# 1  enhance the customer experience at restaurants...     0  0.941487
# 4  make and display more effective advertisements...     1  0.230224
# 5  make physically interactive games for the ente...     2  0.210270
# 0  create novel ways for visual artists to expres...     3  0.128236
# 2  enhance the educational experience of students...     4  0.005833
# 3  increase productivity/efficiency in everyday l...     5 -0.006527

# %%
print paths[['id', 'rank', 'sim']].to_json(orient="records")
# Out:
# [{"id":"p03","rank":0,"sim":0.9414870739},{"id":"p06","rank":1,"sim":0.2302244902},{"id":"p10","rank":2,"sim":0.2102696896},{"id":"p01","rank":3,"sim":0.1282364875},{"id":"p04","rank":4,"sim":0.0058327429},{"id":"p05","rank":5,"sim":-0.0065265894}]

# %%
potential_matches.head()
# Out:
#                                               idea 1  \
# 0  Using the fabric on jackets, to help with cold...
# 1  Hang on the wall and display family pictures t...
# 2      Use the fabric as a projector to watch movies
# 3  An electronic shirt that connects to a compute...
# 4  Having your laptop on the displayed on your co...
#
#                                               idea 2  \
# 0  Using it on camping gears, like tents. Allow i...
# 1  Use as a stealth device for soldiers to get be...
# 2           Use the fabric for office presentations.
# 3  A kids' backpack with changeable images and co...
# 4  Being able to change the patterns on your clot...
#
#                                               idea 3  \
# 0  Using the material on cars. Maybe on the car s...
# 1  Hang on the side of a house, use as a projecto...
# 2              Hang the fabric on a wall as artwork.
# 3  Wearable picture frames that change pictures t...
# 4  Watching movies or using a tablet on the fabri...
#
#                                               idea 4  \
# 0  Airbags on car. Maybe the material can be bett...
# 1  Dress your children in them, let them keep eac...
# 2  Use the fabric as an interactive play set for ...
# 3  WiFi connectivity which could be used to searc...
# 4  Changing the color of your carpet or curtains ...
#
#                                               idea 5  \
# 0  Use it on blankets for little children. It can...
# 1  Be able to use your computer on the go, on any...
# 2  Use the fabric to support your team during spo...
# 3  Built in tools such as calculators and organiz...
# 4  Using this at work to present things on your c...
#
#                                               idea 6  p01  p03  p04  p05  p06  \
# 0    Public transportation. Use it as a better seat.    4    3    1    3    3
# 1  Use for small children to play video games on ...    2    3    4    3    3
# 2         Use the fabric as a virtual drawing board.    1    3    4    3    3
# 3  Post-It Notes that would remind you of importa...    1    1    3    3    1
# 4                      To create patterns on diapers    3    2    3    1    1
#
#    p10
# 0    1
# 1    3
# 2    1
# 3    1
# 4    1

# %%
potential_matches = pd.read_csv("/Users/jchan/Google Drive/Research Docs/IdeaGens/Productive-Fixation/prototyping automated matching.csv")
potential_matches['match_p01'] = [float(i) for i in potential_matches['p01']]
potential_matches['match_p03'] = [float(i) for i in potential_matches['p03']]
potential_matches['match_p04'] = [float(i) for i in potential_matches['p04']]
potential_matches['match_p05'] = [float(i) for i in potential_matches['p05']]
potential_matches['match_p06'] = [float(i) for i in potential_matches['p06']]
potential_matches['match_p10'] = [float(i) for i in potential_matches['p10']]
for i, row in potential_matches.iterrows():
    ideaBag = " ".join([row['idea 1'], row['idea 2'], row['idea 3'], row['idea 4'], row['idea 5'], row['idea 6']])
    best_paths = choose_best_path(ideaBag, dict_fabric, lsi_fabric, index, paths)
    for pathID in best_paths['id']:
        column = "match_%s" %pathID
        value = best_paths[best_paths['id'] == pathID]['sim'].values[0] + potential_matches.loc[i, column]
        potential_matches.set_value(i, column, float(value))
    #print ideaBag
    #print best_paths[['path', 'sim']]

# %%
potential_matches
# Out:
#                                                idea 1  \
# 0   Using the fabric on jackets, to help with cold...
# 1   Hang on the wall and display family pictures t...
# 2       Use the fabric as a projector to watch movies
# 3   An electronic shirt that connects to a compute...
# 4   Having your laptop on the displayed on your co...
# 5   Create an entire wardrobe form a single suit. ...
# 6   put it on a wall as a poster that can change t...
# 7   When purchasing something on line, this featur...
# 8   Wear your big work presentation on your work c...
# 9   It could be used as a cheaper means of televis...
# 10  A shirt which changes color in response to tou...
# 11  The fabric display can be part of emergency ki...
# 12               see if patterns or colors coordinate
# 13  could be used to replace the blackboard and ev...
# 14  Use it as an interactive t shirt. Something wh...
# 15                     use it to watch movies at home
# 16           Shirts that you can change the images on
# 17  record video of self reading a book. Hang in a...
# 18             Clothes with customizable appearances.
# 19  Workers outfits that can change depending on t...
# 20  immersive game playing/video. set up a spheric...
# 21            Could be used for advertising purposes.
# 22  place the cloth over a kitchen table to detect...
# 23  I don't support this idea at all, but one use ...
# 24  It can be given as a gift to someone with spec...
# 25                                crafts for children
# 26  Displaying the fabric for cooking recipes in t...
# 27  MAKE A TSHIRT THAT CAN CHANGE TO VARIOUS PICTU...
# 28  A display on a purse or sleeve showing the tim...
# 29  clothes that change color based on your mood b...
#
#                                                idea 2  \
# 0   Using it on camping gears, like tents. Allow i...
# 1   Use as a stealth device for soldiers to get be...
# 2            Use the fabric for office presentations.
# 3   A kids' backpack with changeable images and co...
# 4   Being able to change the patterns on your clot...
# 5   Have walking billboards. Have commercials, and...
# 6   put a picture of your spouse on it and was you...
# 7   scratch that last idea, i just realized the de...
# 8   Change the color of your clothes if you're out...
# 9   It could be used to make underwater screens wh...
# 10                      fun interactive throw pillows
# 11  You can use the fabric display technique durin...
# 12  use as a teaching tool for preschoolers and to...
# 13  this maybe a lucrative product for internet or...
# 14  You could use it to make color changing draper...
# 15         teachers can use it to teach a lesson plan
# 16  Touch screens that fold up like handkerchiefs....
# 17  Have older relative, maybe mom or grandmother,...
# 18  Cheaper alternative for touch displays where h...
# 19  A tent could have it to produce stars inside t...
# 20  curtains that change colors/play background im...
# 21  Used to create custom t-shirt and other clothi...
# 22         in the room as very small insects detector
# 23     displaying nametags on clothing at conventions
# 24  It can be a tool to show your emotions dependi...
# 25                                     demonstrations
# 26  Displayed in hotel bathrooms, etc for marking ...
# 27      MAKE JEANS THAT CAN TURN TO DIFFERENT DESIGNS
# 28  Use it to put logos of corporate sponsors on a...
# 29  a flag that changes colors based on the temp r...
#
#                                                idea 3  \
# 0   Using the material on cars. Maybe on the car s...
# 1   Hang on the side of a house, use as a projecto...
# 2               Hang the fabric on a wall as artwork.
# 3   Wearable picture frames that change pictures t...
# 4   Watching movies or using a tablet on the fabri...
# 5   Use for warnings and public announcements duri...
# 6   put a picture of the family on it and use it f...
# 7   People can make clothes, or bags with detailed...
# 8   A rug shaped like a piano that plays in tune w...
# 9   There are many possible military applications....
# 10  A tablecloth which would be lit up at each per...
# 11  use fabric for billboards instead of electroni...
# 12    to use as a useful and decorative "white" board
# 13  because of it's small size could help small fi...
# 14  You could make sports jerseys where you can ch...
# 15     professors can use it to give a visual lecture
# 16  Interactive tent could show you the weather, i...
# 17  display master of animal on some sort of toy t...
# 18  Create page-like fabric for ebook display for ...
# 19  Have clothes that will allow the designs to ch...
# 20                         clothes that change colors
# 21  Could be used to communicate with others silently
# 22    on a machine to paint and dry a freshly painted
# 23  visual displays in public places - it would be...
# 24     Great for a more comfortable movie experience!
# 25                                     work projekcts
# 26      Clothes that have interchangeable logos, etc.
# 27  MAKE HEADBANDS THAT EXPRESS HOW YOU FEEL FOR T...
# 28  Use it on pillows and bedding in hospitals to ...
# 29  a car wrap that allows any custom color or pat...
#
#                                                idea 4  \
# 0   Airbags on car. Maybe the material can be bett...
# 1   Dress your children in them, let them keep eac...
# 2   Use the fabric as an interactive play set for ...
# 3   WiFi connectivity which could be used to searc...
# 4   Changing the color of your carpet or curtains ...
# 5   Synchronization of clothing for public display...
# 6   put weird pictures on it to make a great costu...
# 7   it would be easier for people to make designs ...
# 8   Personalized billboards from companies that re...
# 9   It could be used for cheap and makeshift educa...
# 10  light up bedding that helps children who are a...
# 11                         use for walking billboards
# 12                   use for a light show at an event
# 13  obviously has use in the military, navy or air...
# 14  Make billboards that can display in real time ...
# 15         students can use it to give presentations.
# 16  TVs or monitors with fabric screens would be m...
# 17  Billboards equipped with this would be inexpen...
# 18  Fabric overlay for use on building walls with ...
# 19  Use it on interior of cars. That way when a sa...
# 20  modeling dynamic processes with shaped cloth a...
# 21  Useful for custom-designed furniture designs, ...
# 22                 to put into a room to watch movies
# 23   clothing with smartphone technology in a display
# 24  This can be used as a fun family portrait. So ...
# 25                                 business proposals
# 26  Welcome rugs with many different styles showin...
# 27        PUT COMPANY INFOMMERCIAL ON BACK OF TSHIRTS
# 28   You can create shirts with watches in the cuffs.
# 29  interactive movie theater experience, like cho...
#
#                                                idea 5  \
# 0   Use it on blankets for little children. It can...
# 1   Be able to use your computer on the go, on any...
# 2   Use the fabric to support your team during spo...
# 3   Built in tools such as calculators and organiz...
# 4   Using this at work to present things on your c...
# 5   Mobile social displays. Wearers can choose to ...
# 6   using the touch feature, have it change pictur...
# 7   people could be very creative and make things ...
# 8   Help advertise your new movie by wearing the t...
# 9   It could usher in a new age of digital interio...
# 10  fun bath towels which light up when being used...
# 11                                  use to make books
# 12  to see if you would like a certain color or wa...
# 13  say goodbye to the conventional television set...
# 14  Make a shirt that allows other to promote item...
# 15                 use it to display life size photos
# 16  Pop up televisions or monitors, on a plastic s...
# 17  Create a kind of interactive card like a buss ...
# 18  A more convenient way to do maritime flag sign...
# 19  People can drape a large fabric anywhere and u...
# 20            phone conferencing through your clothes
# 21  As a way for people to distinguish themselves ...
# 22  for the child's room, they can see their favor...
# 23  display images on curtains before/after stage ...
# 24  This fabric could be used as a school uniform,...
# 25                                              games
# 26  Sofa sets that have can be changed to differen...
# 27  STORES CAN USE AS AWNING TO DISPLAY THEIR VARI...
# 28  You can make flags or banners that emit light....
# 29   you could just have your bed also be A tv screen
#
#                                                idea 6  p01  p03  p04  p05  \
# 0     Public transportation. Use it as a better seat.    4    3    1    3
# 1   Use for small children to play video games on ...    2    3    4    3
# 2          Use the fabric as a virtual drawing board.    1    3    4    3
# 3   Post-It Notes that would remind you of importa...    1    1    3    3
# 4                       To create patterns on diapers    3    2    3    1
# 5   Emergency applications that will cause the fab...    3    4    4    1
# 6   you can have different colored shirts or pants...    1    1    4    4
# 7   the clothing industry would be able to use thi...    4    1    4    3
# 8   Have an entire room in the house be a movie pr...    1    1    1    2
# 9   It could introduce many new possibilities for ...    4    1    2    4
# 10                                     pocket squares    2    2    2    2
# 11                            use to make stage props    1    4    4    2
# 12  make it a portable wall decorator. you can cha...    1    3    1    1
# 13  you could change colors of entire room, home, ...    1    4    1    1
# 14  Use it as a fabric for beds that can be change...    2    2    3    4
# 15                     use it as a video game monitor    4    4    4    1
# 16  Blankets or sheets that were also sex toys wou...    2    1    2    1
# 17  Make Tee shirts with an interactive game to am...    4    1    3    1
# 18  Used as wrapping fabric for presents, with pro...    1    4    1    2
# 19  Sports clothes that can change through out the...    1    4    2    3
# 20  shirt display of running time, heart rate, blo...    1    1    1    1
# 21  A way to display how people feel (sort of like...    2    4    1    4
# 22     in movie theaters to make them more ajustab...    3    3    1    1
# 23                            customizable dress ties    1    2    1    1
# 24  I think this fabric can be wearable and if peo...    4    2    2    4
# 25                                  displaying movies    2    1    3    1
# 26  Portable magazines - can be used to store favo...    1    1    3    4
# 27               MAKE SNEAKERS THAT CAN CHANGE COLORS    1    3    4    2
# 28  You can use it on a keychain so that it will l...    2    2    2    1
# 29  pocket square with custom designs for suit aff...    1    1    1    1
#
#     p06  p10  match_p01  match_p03  match_p04  match_p05  match_p06  match_p10
# 0     3    1   4.080323   3.015587   1.037860   2.978731   3.155870   0.994629
# 1     3    3   2.048248   3.072212   3.987101   3.006807   3.131394   3.215973
# 2     3    1   1.015510   3.011634   3.996046   2.999689   2.985805   1.074702
# 3     1    1   1.123065   1.216565   3.040478   3.263555   1.134559   1.002665
# 4     1    1   3.296930   2.023031   3.090648   0.990136   0.979459   1.066662
# 5     4    4   3.177287   4.159947   4.019974   1.003061   4.409213   4.087617
# 6     4    3   1.119689   1.026203   4.024745   4.116953   4.103632   3.182248
# 7     3    1   4.146161   1.222403   4.024818   3.047048   3.173672   1.138935
# 8     4    2   1.168519   0.995969   1.029374   2.210205   4.122792   2.004479
# 9     2    4   4.148058   1.196253   2.032621   4.041125   2.231599   4.108010
# 10    2    3   1.998219   1.997602   2.000033   2.074320   1.995360   3.177562
# 11    1    3   1.095655   4.149255   4.067621   2.015810   1.517484   3.121797
# 12    4    1   1.071275   3.023840   1.121256   0.993636   4.059953   1.083856
# 13    4    2   1.072500   3.977261   1.065286   1.026293   4.051746   1.997941
# 14    2    1   2.213409   2.049094   3.016675   4.154605   2.388998   1.240649
# 15    4    4   4.100730   4.092862   4.128480   1.010244   4.206067   4.005715
# 16    4    3   2.140875   1.049744   2.107007   1.039238   4.028571   3.131646
# 17    4    2   4.192691   1.135319   3.091635   1.018528   4.389168   2.239128
# 18    2    3   1.242749   4.116574   1.019610   2.132511   2.233799   2.996484
# 19    3    1   1.176393   4.034358   2.183549   3.185427   3.006587   1.006263
# 20    2    1   1.269260   1.294752   1.009522   1.221047   2.373919   0.990929
# 21    3    1   2.140053   4.083706   1.030040   4.007617   3.136591   0.999337
# 22    2    2   3.002202   3.052781   1.022203   1.003306   2.081105   2.058853
# 23    1    1   1.162207   2.225907   1.014317   1.007994   1.295036   1.013310
# 24    1    4   4.161525   2.020655   2.130489   4.029446   0.999422   4.003954
# 25    3    2   2.121585   1.029136   2.949804   1.011952   2.995339   2.252770
# 26    3    1   1.001189   1.011123   2.994394   4.111120   3.028040   1.020173
# 27    3    4   1.227298   3.069794   4.038647   2.052037   3.382801   4.209428
# 28    2    4   2.366982   2.106913   2.025780   1.119256   2.355556   4.105745
# 29    3    4   1.174685   1.020792   1.007144   1.063585   3.072518   4.087087

# %%
potential_matches.to_csv("../test/prototyping automated matching.csv")
